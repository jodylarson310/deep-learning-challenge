# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
import os
import h5py
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN", "NAME"])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
app_unique = application_df.nunique()
app_unique
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Check data types
app_dtypes = application_df.dtypes
app_dtypes
# Out:
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
# Look at APPLICATION_TYPE value counts for binning
app_value_counts = application_df['APPLICATION_TYPE'].value_counts()
app_value_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
app_type_cutoff = 500

application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() < app_type_cutoff].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_value_counts = application_df['CLASSIFICATION'].value_counts()
class_value_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts_greater_than_1 = class_value_counts[class_value_counts > 1]
class_counts_greater_than_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
class_cutoff = 1000

classifications_to_replace = application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() < class_cutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Look at ASK_AMT value counts for binning
ask_value_counts = application_df['ASK_AMT'].value_counts()
ask_value_counts
# Out:
# 5000        25398
# 10478           3
# 15583           3
# 63981           3
# 6725            3
#             ...
# 5371754         1
# 30060           1
# 43091152        1
# 18683           1
# 36500179        1
# Name: ASK_AMT, Length: 8747, dtype: int64

# %%
bins = [0, 5000, 10000, 50000, 100000, 500000, 1000000, 10000000, 100000000, float('inf')]
ask_amt_bins = pd.cut(application_df['ASK_AMT'], bins=bins, labels=['0-5k', '5k-10k', '10k-50k', '50k-100k','100k-500k', '500k-1M', '1M-10M', '10M-100M', '100M+'])
ask_amt_bins.value_counts()
# Out:
# 0-5k         25398
# 10k-50k       2398
# 100k-500k     2304
# 50k-100k      1423
# 1M-10M        1165
# 500k-1M        650
# 5k-10k         549
# 10M-100M       311
# 100M+          101
# Name: ASK_AMT, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categorical_columns = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']
dummy_df = pd.get_dummies(application_df, columns=categorical_columns, drop_first=True)
dummy_df
# Out:
#         ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0          5000              1                     1                     0
# 1        108590              1                     0                     0
# 2          5000              0                     0                     0
# 3          6692              1                     0                     0
# 4        142590              1                     0                     0
# ...         ...            ...                   ...                   ...
# 34294      5000              0                     0                     0
# 34295      5000              0                     0                     0
# 34296      5000              0                     0                     0
# 34297      5000              1                     0                     0
# 34298  36500179              0                     0                     0
#
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = dummy_df["IS_SUCCESSFUL"].values
X = dummy_df.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-13-08aab865d20f>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = dummy_df.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Optimize, Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  16
hidden_nodes_layer2 = 8
hidden_nodes_layer3 = 8

asco2 = tf.keras.models.Sequential()

# First hidden layer
asco2.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
asco2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
asco2.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
asco2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
asco2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 16)                592
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 1)                 9
#
# ...
# Total params: 809 (3.16 KB)
# Trainable params: 809 (3.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
asco2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = asco2.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 8s 6ms/step - loss: 0.5886 - accuracy: 0.7166
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5630 - accuracy: 0.7277
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5583 - accuracy: 0.7297
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5559 - accuracy: 0.7285
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5541 - accuracy: 0.7322
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5526 - accuracy: 0.7317
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7329
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5510 - accuracy: 0.7336
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7334
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = asco2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5509 - accuracy: 0.7264 - 523ms/epoch - 2ms/step
# Loss: 0.5508784651756287, Accuracy: 0.7264139652252197

# %%
# Export our model to HDF5 file
from google.colab import drive
drive.mount('/content/gdrive')

directory_path = '/content/gdrive/MyDrive/Deep Learning Challenge'

if not os.path.exists(directory_path):
    os.makedirs(directory_path)

filename = 'AlphabetSoupCharity_Optimization2.h5'

fullpath = os.path.join(directory_path,filename)

asco2.save(fullpath)

print(f"HDF5 file saved to: {fullpath}")
# Out:
# Mounted at /content/gdrive
# HDF5 file saved to: /content/gdrive/MyDrive/Deep Learning Challenge/AlphabetSoupCharity_Optimization2.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
